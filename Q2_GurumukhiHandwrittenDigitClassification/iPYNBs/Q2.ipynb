# %% [markdown]
# ### Importing Libraries

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image

print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# #### Loading train and test data

# %%
root_data_dir = './drive/MyDrive/IIT-J/Semester1/Assignments/ML/Assignment-Fractal3/data/GurNum/'
train_data_dir = root_data_dir + 'train'
test_data_dir = root_data_dir + 'val'

# %% [markdown]
# ###### Loading data into dataframe

# %%
def read_folder_class_data(folder_path):
  df = pd.DataFrame(columns = ["ImageName", "Class"])
  for class_dir in os.listdir(folder_path):
    for image in os.listdir(folder_path+"/"+class_dir):
      df.loc[len(df)+1] = [image, class_dir]
  return df

# %%
train_df = read_folder_class_data(train_data_dir)
test_df = read_folder_class_data(test_data_dir)

# %%
print("Number of training records: {}".format(len(train_df)))
print("Number of testing records: {}".format(len(test_df)))
# Out:
# Number of training records: 1000
# Number of testing records: 178

# %%
print("Train Data Class Distribution: ")
train_df.Class.value_counts()
# Out:
# Train Data Class Distribution:
# 9    100
# 8    100
# 7    100
# 6    100
# 5    100
# 4    100
# 3    100
# 2    100
# 1    100
# 0    100
# Name: Class, dtype: int64

# %% [markdown]
# ###### Loading image data and labels into arrays

# %%
# Custom function to 
def read_image(imagePath):
  img = Image.open(imagePath).convert("L")
  return np.array(img)

# %%
train_images = train_df.apply(lambda r: read_image(train_data_dir + "/" + r['Class'] + "/" + r['ImageName']) , axis=1).tolist()
test_images = test_df.apply(lambda r: read_image(test_data_dir + "/" + r['Class'] + "/" + r['ImageName']) , axis=1).tolist()

# %%
train_images = np.array(train_images)
test_images = np.array(test_images)

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
train_images.shape
# Out:
# (1000, 32, 32)

# %%
train_labels = np.array(train_df['Class'].tolist()).astype(int)
test_labels = np.array(test_df['Class'].tolist()).astype(int)

# %% [markdown]
# ###### Randomly checking the dataset

# %%
plt.figure(figsize=(10,10))
random_indices = np.random.randint(low=0, high=len(train_images), size=25)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    random_index = random_indices[i]
    plt.imshow(train_images[random_index], cmap=plt.cm.binary)
    plt.xlabel(train_labels[random_index])
plt.show()

# %% [markdown]
# #### Building the model:

# %%
def define_model():
  model = tf.keras.Sequential([
      tf.keras.layers.Flatten(input_shape=(32, 32)),
      tf.keras.layers.Dense(128, activation='relu', kernel_initializer="he_normal"),
      tf.keras.layers.Dense(64, activation='relu', kernel_initializer="he_normal"),
      tf.keras.layers.Dense(32, activation='relu', kernel_initializer="he_normal"),
      tf.keras.layers.Dropout(0.4),
      tf.keras.layers.Dense(10)
  ])
  return model

# %%
def compile_model(model):
  model.compile(optimizer=keras.optimizers.Adam(learning_rate=3e-4),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

# %%
model = define_model()
compile_model(model)
model.summary()
# Out:
# Model: "sequential_71"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_59 (Flatten)        (None, 1024)              0
#
#  dense_208 (Dense)           (None, 128)               131200
#
#  dense_209 (Dense)           (None, 64)                8256
#
#  dense_210 (Dense)           (None, 32)                2080
#
#  dropout_27 (Dropout)        (None, 32)                0
#
#  dense_211 (Dense)           (None, 10)                330
#
# =================================================================
# Total params: 141,866
# Trainable params: 141,866
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Training the model

# %%
no_epoch = 100
history = model.fit(train_images, train_labels, validation_data=(test_images, test_labels), epochs=no_epoch)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 13ms/step - loss: 2.2186 - accuracy: 0.2320 - val_loss: 1.8806 - val_accuracy: 0.5056
# Epoch 2/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.6320 - accuracy: 0.4720 - val_loss: 1.3413 - val_accuracy: 0.7528
# Epoch 3/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.2141 - accuracy: 0.6110 - val_loss: 0.9913 - val_accuracy: 0.7753
# Epoch 4/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0154 - accuracy: 0.6780 - val_loss: 0.7617 - val_accuracy: 0.8090
# Epoch 5/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.8040 - accuracy: 0.7540 - val_loss: 0.6344 - val_accuracy: 0.8371
# Epoch 6/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.7044 - accuracy: 0.7810 - val_loss: 0.5219 - val_accuracy: 0.8876
# Epoch 7/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6039 - accuracy: 0.8050 - val_loss: 0.4245 - val_accuracy: 0.9045
# Epoch 8/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5917 - accuracy: 0.8050 - val_loss: 0.3801 - val_accuracy: 0.9157
# Epoch 9/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4865 - accuracy: 0.8490 - val_loss: 0.3348 - val_accuracy: 0.9101
# Epoch 10/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4776 - accuracy: 0.8470 - val_loss: 0.3167 - val_accuracy: 0.9213
# Epoch 11/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4457 - accuracy: 0.8520 - val_loss: 0.3029 - val_accuracy: 0.9213
# Epoch 12/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4107 - accuracy: 0.8670 - val_loss: 0.2834 - val_accuracy: 0.9213
# Epoch 13/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4111 - accuracy: 0.8710 - val_loss: 0.2556 - val_accuracy: 0.9157
# Epoch 14/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3377 - accuracy: 0.9040 - val_loss: 0.2356 - val_accuracy: 0.9326
# Epoch 15/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3414 - accuracy: 0.8800 - val_loss: 0.2592 - val_accuracy: 0.9270
# Epoch 16/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3061 - accuracy: 0.8980 - val_loss: 0.2189 - val_accuracy: 0.9326
# Epoch 17/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3111 - accuracy: 0.9030 - val_loss: 0.2648 - val_accuracy: 0.9045
# Epoch 18/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2720 - accuracy: 0.9070 - val_loss: 0.1734 - val_accuracy: 0.9438
# Epoch 19/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.2254 - accuracy: 0.9270 - val_loss: 0.1962 - val_accuracy: 0.9382
# Epoch 20/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2533 - accuracy: 0.9100 - val_loss: 0.1830 - val_accuracy: 0.9270
# Epoch 21/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2601 - accuracy: 0.9230 - val_loss: 0.2097 - val_accuracy: 0.9326
# Epoch 22/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2170 - accuracy: 0.9310 - val_loss: 0.1625 - val_accuracy: 0.9382
# Epoch 23/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2303 - accuracy: 0.9230 - val_loss: 0.1766 - val_accuracy: 0.9270
# Epoch 24/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1990 - accuracy: 0.9360 - val_loss: 0.1671 - val_accuracy: 0.9438
# Epoch 25/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2403 - accuracy: 0.9200 - val_loss: 0.1698 - val_accuracy: 0.9494
# Epoch 26/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.1815 - accuracy: 0.9390 - val_loss: 0.1770 - val_accuracy: 0.9326
# Epoch 27/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1787 - accuracy: 0.9460 - val_loss: 0.1758 - val_accuracy: 0.9438
# Epoch 28/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1831 - accuracy: 0.9320 - val_loss: 0.1485 - val_accuracy: 0.9494
# Epoch 29/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1542 - accuracy: 0.9530 - val_loss: 0.1555 - val_accuracy: 0.9494
# Epoch 30/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1749 - accuracy: 0.9370 - val_loss: 0.1671 - val_accuracy: 0.9382
# Epoch 31/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1461 - accuracy: 0.9560 - val_loss: 0.1655 - val_accuracy: 0.9607
# Epoch 32/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1497 - accuracy: 0.9470 - val_loss: 0.1720 - val_accuracy: 0.9326
# Epoch 33/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1443 - accuracy: 0.9480 - val_loss: 0.1366 - val_accuracy: 0.9607
# Epoch 34/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1508 - accuracy: 0.9460 - val_loss: 0.1501 - val_accuracy: 0.9551
# Epoch 35/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1358 - accuracy: 0.9550 - val_loss: 0.1519 - val_accuracy: 0.9494
# Epoch 36/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1382 - accuracy: 0.9540 - val_loss: 0.1834 - val_accuracy: 0.9438
# Epoch 37/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1335 - accuracy: 0.9540 - val_loss: 0.1820 - val_accuracy: 0.9551
# Epoch 38/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1235 - accuracy: 0.9620 - val_loss: 0.1346 - val_accuracy: 0.9551
# Epoch 39/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1193 - accuracy: 0.9610 - val_loss: 0.1495 - val_accuracy: 0.9551
# Epoch 40/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1000 - accuracy: 0.9690 - val_loss: 0.1551 - val_accuracy: 0.9607
# Epoch 41/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1189 - accuracy: 0.9570 - val_loss: 0.1423 - val_accuracy: 0.9663
# Epoch 42/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1242 - accuracy: 0.9550 - val_loss: 0.1731 - val_accuracy: 0.9551
# Epoch 43/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0996 - accuracy: 0.9720 - val_loss: 0.1782 - val_accuracy: 0.9551
# Epoch 44/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1178 - accuracy: 0.9590 - val_loss: 0.1516 - val_accuracy: 0.9551
# Epoch 45/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0892 - accuracy: 0.9750 - val_loss: 0.1631 - val_accuracy: 0.9663
# Epoch 46/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0841 - accuracy: 0.9680 - val_loss: 0.1446 - val_accuracy: 0.9494
# Epoch 47/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.1055 - accuracy: 0.9600 - val_loss: 0.1622 - val_accuracy: 0.9438
# Epoch 48/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0844 - accuracy: 0.9670 - val_loss: 0.1591 - val_accuracy: 0.9607
# Epoch 49/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0776 - accuracy: 0.9710 - val_loss: 0.1856 - val_accuracy: 0.9607
# Epoch 50/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0984 - accuracy: 0.9630 - val_loss: 0.1690 - val_accuracy: 0.9607
# Epoch 51/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0920 - accuracy: 0.9710 - val_loss: 0.1512 - val_accuracy: 0.9607
# Epoch 52/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0927 - accuracy: 0.9660 - val_loss: 0.1734 - val_accuracy: 0.9382
# Epoch 53/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1021 - accuracy: 0.9630 - val_loss: 0.2014 - val_accuracy: 0.9607
# Epoch 54/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0798 - accuracy: 0.9720 - val_loss: 0.1540 - val_accuracy: 0.9607
# Epoch 55/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0675 - accuracy: 0.9800 - val_loss: 0.1419 - val_accuracy: 0.9494
# Epoch 56/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0864 - accuracy: 0.9710 - val_loss: 0.1755 - val_accuracy: 0.9494
# Epoch 57/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0745 - accuracy: 0.9760 - val_loss: 0.1620 - val_accuracy: 0.9607
# Epoch 58/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0740 - accuracy: 0.9760 - val_loss: 0.1840 - val_accuracy: 0.9494
# Epoch 59/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0699 - accuracy: 0.9800 - val_loss: 0.1926 - val_accuracy: 0.9607
# Epoch 60/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0660 - accuracy: 0.9770 - val_loss: 0.1875 - val_accuracy: 0.9663
# Epoch 61/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0782 - accuracy: 0.9690 - val_loss: 0.2039 - val_accuracy: 0.9607
# Epoch 62/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0691 - accuracy: 0.9800 - val_loss: 0.2373 - val_accuracy: 0.9326
# Epoch 63/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0671 - accuracy: 0.9800 - val_loss: 0.1638 - val_accuracy: 0.9607
# Epoch 64/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0714 - accuracy: 0.9700 - val_loss: 0.1642 - val_accuracy: 0.9607
# Epoch 65/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0507 - accuracy: 0.9860 - val_loss: 0.1513 - val_accuracy: 0.9607
# Epoch 66/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0534 - accuracy: 0.9830 - val_loss: 0.1670 - val_accuracy: 0.9663
# Epoch 67/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0590 - accuracy: 0.9740 - val_loss: 0.1771 - val_accuracy: 0.9551
# Epoch 68/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0497 - accuracy: 0.9850 - val_loss: 0.1928 - val_accuracy: 0.9551
# Epoch 69/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0677 - accuracy: 0.9730 - val_loss: 0.1775 - val_accuracy: 0.9607
# Epoch 70/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0563 - accuracy: 0.9780 - val_loss: 0.1639 - val_accuracy: 0.9663
# Epoch 71/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0608 - accuracy: 0.9810 - val_loss: 0.1667 - val_accuracy: 0.9663
# Epoch 72/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0594 - accuracy: 0.9810 - val_loss: 0.1605 - val_accuracy: 0.9551
# Epoch 73/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0503 - accuracy: 0.9820 - val_loss: 0.1960 - val_accuracy: 0.9607
# Epoch 74/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0503 - accuracy: 0.9820 - val_loss: 0.2010 - val_accuracy: 0.9551
# Epoch 75/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0509 - accuracy: 0.9810 - val_loss: 0.1770 - val_accuracy: 0.9607
# Epoch 76/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0563 - accuracy: 0.9820 - val_loss: 0.1594 - val_accuracy: 0.9607
# Epoch 77/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0399 - accuracy: 0.9880 - val_loss: 0.1954 - val_accuracy: 0.9663
# Epoch 78/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0572 - accuracy: 0.9850 - val_loss: 0.1739 - val_accuracy: 0.9607
# Epoch 79/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0365 - accuracy: 0.9910 - val_loss: 0.1772 - val_accuracy: 0.9663
# Epoch 80/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0369 - accuracy: 0.9860 - val_loss: 0.2030 - val_accuracy: 0.9663
# Epoch 81/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0466 - accuracy: 0.9860 - val_loss: 0.1929 - val_accuracy: 0.9494
# Epoch 82/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0433 - accuracy: 0.9860 - val_loss: 0.1903 - val_accuracy: 0.9607
# Epoch 83/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0394 - accuracy: 0.9840 - val_loss: 0.1954 - val_accuracy: 0.9607
# Epoch 84/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0393 - accuracy: 0.9900 - val_loss: 0.2223 - val_accuracy: 0.9551
# Epoch 85/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0353 - accuracy: 0.9890 - val_loss: 0.1789 - val_accuracy: 0.9663
# Epoch 86/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0539 - accuracy: 0.9790 - val_loss: 0.1944 - val_accuracy: 0.9551
# Epoch 87/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0299 - accuracy: 0.9900 - val_loss: 0.1693 - val_accuracy: 0.9551
# Epoch 88/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0396 - accuracy: 0.9850 - val_loss: 0.2120 - val_accuracy: 0.9663
# Epoch 89/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0492 - accuracy: 0.9830 - val_loss: 0.2156 - val_accuracy: 0.9551
# Epoch 90/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0437 - accuracy: 0.9830 - val_loss: 0.1789 - val_accuracy: 0.9607
# Epoch 91/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0610 - accuracy: 0.9780 - val_loss: 0.1679 - val_accuracy: 0.9494
# Epoch 92/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0346 - accuracy: 0.9930 - val_loss: 0.1957 - val_accuracy: 0.9663
# Epoch 93/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0479 - accuracy: 0.9860 - val_loss: 0.1929 - val_accuracy: 0.9663
# Epoch 94/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0431 - accuracy: 0.9860 - val_loss: 0.1978 - val_accuracy: 0.9551
# Epoch 95/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0406 - accuracy: 0.9870 - val_loss: 0.1812 - val_accuracy: 0.9663
# Epoch 96/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0367 - accuracy: 0.9920 - val_loss: 0.2110 - val_accuracy: 0.9663
# Epoch 97/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0475 - accuracy: 0.9840 - val_loss: 0.2042 - val_accuracy: 0.9551
# Epoch 98/100
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0421 - accuracy: 0.9820 - val_loss: 0.1943 - val_accuracy: 0.9663
# Epoch 99/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0446 - accuracy: 0.9840 - val_loss: 0.1738 - val_accuracy: 0.9663
# Epoch 100/100
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0352 - accuracy: 0.9880 - val_loss: 0.1821 - val_accuracy: 0.9663

# %% [markdown]
# #### Evaluating the model

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 6/6 - 0s - loss: 0.1821 - accuracy: 0.9663 - 52ms/epoch - 9ms/step
#
# Test accuracy: 0.966292142868042

# %% [markdown]
# #### Visualizing training graph

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(no_epoch)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
root_model_dir = "./Q2_GurumukhiHandwrittenDigitClassification/saved_model/"
current_model_dir = root_model_dir+"GurNum_MLP/"
model.save(current_model_dir)
with open(current_model_dir+"model_config.json", "w") as f:
  f.write(model.to_json())
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
rm -r my_model
